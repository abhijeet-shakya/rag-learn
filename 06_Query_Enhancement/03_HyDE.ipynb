# %% [markdown]
# ### Hypothetical Document Embeddings(HyDE)
# HyDE is a retrival technique where, instead of **embedding the user's query directly, we first generate a hypothetical answer(document) to the query usint llm** - and then embedded the hypothetical document to search your vector store.
#
# ##### Hyde bridges the gap b/w user intent and relevent content, especially when:
# 1. Queries are Short
# 2. Language mismatch between query and documents
# 3. You want to retrieve based on answer content, not question words.

# %%
from langchain_classic.document_loaders import WikipediaLoader
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS, Chroma
from langchain.chat_models import init_chat_model
from langchain_classic.output_parsers import StructuredOutputParser
from langchain_classic.prompts.chat import SystemMessagePromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate

# %%
# 1. Load and chunk your dataset
chunk_size = 300
chunk_overlap = 100

# loading data
loader = WikipediaLoader(query="Steve Jobs", load_max_docs=5)
documents = loader.load()

# text splitting
text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
docs = text_splitter.split_documents(documents=documents)
# docs

# %%
# 2. Build vector Store
embedding_model = HuggingFaceEmbeddings(model="all-MiniLM-L6-v2")
vector_store = FAISS.from_documents(docs, embedding_model)

# %%
# 3. Setup the LLM you'l use to generate hypothetical answers
from dotenv import load_dotenv
load_dotenv()

llm = init_chat_model("groq:groq/compound-mini")
llm
# Out:
# ChatGroq(profile={}, client=<groq.resources.chat.completions.Completions object at 0x0000022535963770>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000022535AFC950>, model_name='groq/compound-mini', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
## Creating vector stores 
db = Chroma.from_documents(documents=docs, embedding=embedding_model, persist_directory="output/steve_jobs")
# create the retriver
base_retriever = db.as_retriever(search_kwargs ={"k":5})

# %%
## Generating a prompt for generating HyDE
def get_hyde_doc(query):
    system_template = """Imagine you are an expert writing a detailed explanation."""
    
    human_template = """Write a detailed hypothetical answer for the topic: {query}"""

    system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
    human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

    chat_prompt = ChatPromptTemplate.from_messages([
        system_message_prompt,
        human_message_prompt
    ])

    messages = chat_prompt.format_prompt(query=query).to_messages()
    
    response = llm.invoke(messages)
    return response.content

# %%
query = "When was Steve Jobs fired from apple?"
print(get_hyde_doc(query=query))
# Out:
# **When Was Steve Jobs Fired from Apple? – A Detailed Account**
#
# *Short answer:*
# Steve Jobs was effectively forced out of Apple in **September 1985** after a board‑level power struggle with then‑CEO John Sculley and other senior executives. The formal resignation of his title as “Head of the Macintosh Division” was submitted on **September 17, 1985**, and by the end of that month he had left the company for good.
#
# Below is a step‑by‑step narrative that explains how and why this happened, the key players involved, and what the aftermath looked like.
#
# ---
#
# ## 1. The Early Years (1976‑1983)
#
# | Year | Event | Significance |
# |------|-------|--------------|
# | **1976** | Steve Jobs, Steve Wozniak, and Ronald Wayne co‑found Apple Computer, Inc. | Jobs becomes the charismatic, product‑obsessed visionary; Wozniak supplies the engineering brilliance. |
# | **1977** | Apple II released | First major commercial success; Apple goes public in 1980. |
# | **1983** | John Sculley, former PepsiCo marketing chief, is recruited as Apple’s CEO. | Jobs, who had previously convinced Sculley to join Pepsi, now works under him. The relationship is initially collaborative but soon becomes strained. |
# | **1984** | Macintosh launched (January) | Jobs spearheads the project, but the product’s high price and limited software ecosystem cause disappointing sales. |
#
# ---
#
# ## 2. Growing Tensions (1984‑1985)
#
# ### 2.1 Divergent Visions
# - **Jobs**: Believed Apple should focus on groundbreaking, design‑first products (Macintosh) even at the cost of short‑term profits.
# - **Sculley**: Pressured by the board to improve margins, increase market share, and keep the Apple II line profitable.
#
# ### 2.2 The “Power Struggle”
# - By mid‑1985, the Macintosh division (run by Jobs) and the Apple II division (run by senior executives loyal to Sculley) were essentially two competing businesses inside the same company.
# - The board grew uneasy about Jobs’ increasingly autocratic management style and his public criticism of Sculley.
#
# ### 2.3 The Board Meeting
# - **Date:** Early September 1985 (exact date varies by source, but the decisive meeting is recorded as **September 16‑17, 1985**).
# - **Outcome:** The board voted to **strip Jobs of his operational authority** over the Macintosh division and to place the division under Sculley’s direct control.
# - **Jobs’ Reaction:** He attempted to rally support from the Macintosh engineering team but found that many senior managers had already aligned with Sculley.
#
# ---
#
# ## 3. The Formal “Firing”
#
# | Date | Action | Details |
# |------|--------|---------|
# | **September 16‑17, 1985** | Board decision | Jobs is removed from his role as head of the Macintosh division. |
# | **September 17, 1985** | Resignation letter | Jobs submits a resignation from Apple’s board of directors and from his executive position. |
# | **Late September 1985** | Exit | Jobs leaves Apple’s campus for the last time, handing over his responsibilities to the new leadership. |
#
# > **Note:** While the term “fired” is commonly used in popular accounts, the technical process was a board‑mandated removal of authority followed by Jobs’ own resignation. In legal terms, he was not terminated as a regular employee; he voluntarily stepped down after being stripped of his power.
#
# ---
#
# ## 4. Aftermath (1985‑1996)
#
# ### 4.1 Jobs’ Next Ventures
# - **NeXT Inc.** (founded 1985): A computer company aimed at the higher‑education and business markets. Although financially modest, NeXT’s software (NeXTSTEP) later became the foundation of macOS.
# - **Pixar** (acquired 1986): Jobs bought the graphics division of Lucasfilm and turned it into the animation powerhouse that produced *Toy Story* (1995) and other hits.
#
# ### 4.2 Apple’s Struggles
# - The Apple II line continued to decline.
# - The Macintosh, now under Sculley’s direction, suffered from a lack of clear vision and market share erosion.
# - By the early 1990s Apple was losing ground to Microsoft’s Windows platform.
#
# ### 4.3 The Return
# - **1996:** Apple acquires NeXT for **$429 million**. The acquisition brings Jobs back as an advisor.
# - **1997:** Jobs is named interim CEO (later “iCEO”) and begins a dramatic turnaround that culminates in the iMac, iPod, iPhone, and iPad.
#
# ---
#
# ## 5. Why the 1985 Ouster Matters
#
# 1. **Leadership Lessons** – The clash illustrates how visionary founders can be at odds with professional managers when growth and profitability become the primary focus.
# 2. **Corporate Governance** – The board’s decision underscores the importance of clear succession planning and the risks of having two competing product lines under separate leadership.
# 3. **Cultural Impact** – Jobs’ departure forced Apple to confront a lack of design‑driven culture, a void that he later restored after his return.
# 4. **Technological Legacy** – NeXT’s software, developed during Jobs’ exile, became the core of Apple’s modern operating systems (macOS, iOS, watchOS, tvOS).
#
# ---
#
# ## 6. Timeline Summary
#
# | Year | Event |
# |------|-------|
# | **1976** | Apple founded |
# | **1983** | John Sculley hired as CEO |
# | **1984** | Macintosh launched |
# | **Sept 1985** | Board removes Jobs from Macintosh leadership; Jobs resigns – effectively “fired” |
# | **1985‑1996** | Jobs leads NeXT and Pixar |
# | **1996** | Apple acquires NeXT |
# | **1997** | Jobs returns as interim CEO |
# | **2001‑2011** | Era of iPod, iPhone, iPad – Jobs’ second tenure |
#
# ---
#
# ## 7. Frequently Asked Follow‑Up Questions
#
# | Question | Answer |
# |----------|--------|
# | **Did Apple ever officially announce “Steve Jobs was fired”?** | No. Apple’s public communications framed the event as a “restructuring” and a “board‑mandated change in leadership.” The phrase “fired” is a media shorthand. |
# | **Was there any legal settlement?** | No lawsuit was filed. Jobs left voluntarily after the board’s decision, and Apple and Jobs later negotiated a settlement regarding his stock options when he returned in 1997. |
# | **How did the market react at the time?** | The immediate market reaction was muted; Apple’s stock was already under pressure from declining Apple II sales. The real impact was felt later as the company’s product line lost direction. |
# | **What can modern CEOs learn from this?** | Balance visionary ambition with operational pragmatism, maintain clear communication with the board, and avoid internal power silos that can lead to destructive infighting. |
#
# ---
#
# ### Bottom Line
#
# Steve Jobs’ departure from Apple was formalized in **mid‑September 1985**, when the board stripped him of his operational authority and he subsequently resigned. The episode set the stage for both Apple’s near‑collapse in the early 1990s and its spectacular resurgence after Jobs’ return—a reminder that even the most iconic founders can be ousted, only to later reshape the very company that once let them go.

# %%
matched_doc = base_retriever.invoke(get_hyde_doc(query))
print(matched_doc)
# Out:
# [Document(metadata={'title': 'Steve Jobs', 'summary': 'Steven Paul Jobs  (February 24, 1955 – October 5, 2011) was an American businessman, inventor, and investor best known for co-founding the technology company Apple Inc. Jobs was also the founder of NeXT and chairman and majority shareholder of Pixar. He was a pioneer of the personal computer revolution of the 1970s and 1980s, along with his early business partner and fellow Apple co-founder Steve Wozniak.\nJobs was born in San Francisco in 1955 and adopted shortly afterwards. He attended Reed College in 1972 before withdrawing that same year. In 1974, he traveled through India, seeking enlightenment before later studying Zen Buddhism. He and Wozniak co-founded Apple in 1976 to further develop and sell Wozniak\'s Apple I personal computer. Together, the duo gained fame and wealth a year later with production and sale of the Apple II, one of the first highly successful mass-produced microcomputers. \nJobs saw the commercial potential of the Xerox Alto in 1979, which was mouse-driven and had a graphical user interface (GUI). This led to the development of the largely unsuccessful Apple Lisa in 1983, followed by the breakthrough Macintosh in 1984, the first mass-produced computer with a GUI. The Macintosh launched the desktop publishing industry in 1985 (for example, the Aldus PageMaker) with the addition of the Apple LaserWriter, the first laser printer to feature vector graphics and PostScript.\nIn 1985, Jobs departed Apple after a long power struggle with the company\'s board and its then-CEO, John Sculley. That same year, Jobs took some Apple employees with him to found NeXT, a computer platform development company that specialized in computers for higher-education and business markets, serving as its CEO. In 1986, he bought the computer graphics division of Lucasfilm, which was spun off independently as Pixar. Pixar produced the first computer-animated feature film, Toy Story (1995), and became a leading animation studio, producing dozens of commercially successful and critically acclaimed films.\nIn 1997, Jobs returned to Apple as CEO after the company\'s acquisition of NeXT. He was largely responsible for reviving Apple, which was on the verge of bankruptcy. He worked closely with British designer Jony Ive to develop a line of products and services that had larger cultural ramifications, beginning with the "Think different" advertising campaign, and leading to the iMac, iTunes, Mac OS X, Apple Store, iPod, iTunes Store, iPhone, App Store, and iPad. Jobs was also a board member at Gap Inc. from 1999 to 2002. In 2003, Jobs was diagnosed with a pancreatic neuroendocrine tumor. He died of tumor-related respiratory arrest in 2011; in 2022, he was posthumously awarded the Presidential Medal of Freedom. Since his death, he has won 141 patents; Jobs holds over 450 patents in total.', 'source': 'https://en.wikipedia.org/wiki/Steve_Jobs'}, page_content="In 1985, Jobs departed Apple after a long power struggle with the company's board and its then-CEO, John Sculley. That same year, Jobs took some Apple employees with him to found NeXT, a computer platform development company that specialized in computers for higher-education and business markets,"), Document(metadata={'summary': 'Steven Paul Jobs  (February 24, 1955 – October 5, 2011) was an American businessman, inventor, and investor best known for co-founding the technology company Apple Inc. Jobs was also the founder of NeXT and chairman and majority shareholder of Pixar. He was a pioneer of the personal computer revolution of the 1970s and 1980s, along with his early business partner and fellow Apple co-founder Steve Wozniak.\nJobs was born in San Francisco in 1955 and adopted shortly afterwards. He attended Reed College in 1972 before withdrawing that same year. In 1974, he traveled through India, seeking enlightenment before later studying Zen Buddhism. He and Wozniak co-founded Apple in 1976 to further develop and sell Woz ...

# %% [markdown]
# #

# %% [markdown]
# # Langchain - HypotheticalDocumentEmbedder

# %%
from langchain_classic.chains.hyde.base import HypotheticalDocumentEmbedder

from langchain_classic.prompts import PromptTemplate
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_classic.document_loaders import TextLoader
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

# %%
# Step: 1 Load and split the documents
loader = TextLoader("langchain.txt", encoding="utf-8")
docs = loader.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
chunks = splitter.split_documents(docs)

# %%
# Step 2: Setup LLM and embedding
base_embedding = HuggingFaceEmbeddings(model="all-MiniLM-L6-v2")
llm = init_chat_model("groq:groq/compound-mini")

# %% [markdown]
# According to the official documentation and Langchain source coe(mapping in PROMPT_MAP), the default options are:
# - web_search
# - sci_fact
# - arguana
# - trec_covid
# - trec_news
# - fiqa
# etc..

# %%
# custom = PromptTemplate.from_template(
#     "Generate a concise hypothetical answer for this topic: {query}"
# )

# Step 3: HyDE Embedder using prompt_key='web_search'01_query_expansion.ipynb
hyde_embedding_function = HypotheticalDocumentEmbedder.from_llm(
    llm=llm,
    base_embeddings=base_embedding,
    prompt_key="web_search"
    # custom_prompt=custom
)

# %% [markdown]
# ## Custom prompt

# %%
custom = PromptTemplate.from_template(
    "Generate a concise hypothetical answer for this topic: {query}"
)

# Step 3: HyDE Embedder using custom_prompt
hyde_embedding_function = HypotheticalDocumentEmbedder.from_llm(
    llm=llm,
    base_embeddings=base_embedding,
    # custom_prompt=custom
)

# %% [markdown]
# ##

# %%
# Step 4: Store documents in Chroma with HyDE embeddings
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=hyde_embedding_function,
    persist_directory="output/langchain"
)

# %%
# Step 5: RAG answer generation prompt
rag_prompt = PromptTemplate.from_template("""
Use the context below to answer the question.
Context:{context}

Question: {input}                                                                      
""")
rag_chain = create_stuff_documents_chain(llm=llm,prompt=rag_prompt)

# %%
# Step 6: Final RAG Pipeline
def hyde_rag_pipeline(query):
    matched_docs = vector_store.similarity_search(query, k=4)
    response = rag_chain.invoke({
        "input": query,
        "context": matched_docs
    })
    return response

# %%
# Step 7: Run example query
query = "What memory modules does Langchain provide?"
answer = hyde_rag_pipeline(query)
print("☑️ Final Answer: \n ", answer)
# Out:
# ☑️ Final Answer:
#   LangChain ships with a variety of built‑in memory classes that you can plug directly into a chain or agent. The most commonly used ones are:
#
# | Memory class | What it does | Typical use‑case |
# |--------------|--------------|-----------------|
# | **ConversationBufferMemory** | Stores the full chat history as a plain text buffer. | Simple bots that need the entire conversation context. |
# | **ConversationBufferWindowMemory** (or **BufferWindowMemory**) | Keeps only the last *k* turns. | Keeps context lightweight while still remembering recent dialogue. |
# | **ConversationSummaryMemory** | Summarizes the whole conversation into a short text that is passed forward. | Long‑running chats where token cost would explode if you kept everything. |
# | **ConversationSummaryBufferMemory** | Combination of a buffer and a periodic summary (keeps recent turns plus a running summary). | Mid‑size conversations where you want both recent detail and overall gist. |
# | **EntityMemory** | Extracts named entities (people, places, objects, etc.) from the dialogue and stores facts about them. | Scenarios that need a “knowledge base” of people, products, dates, etc. |
# | **ConversationKnowledgeGraphMemory** | Builds a graph of entities and their relationships from the chat history. | When you need to reason about how different pieces of information connect. |
# | **VectorStoreRetrieverMemory** | Persists chunks of conversation (or external docs) in a vector store and retrieves the most relevant pieces via semantic search. | Retrieval‑augmented generation (RAG) or long‑term memory across sessions. |
# | **BufferMemory** (generic) | Low‑level buffer that can store raw `BaseMessage` objects or strings. | When you want full control over how messages are formatted. |
# | **CombinedMemory** | Composes two or more memory objects (e.g., a buffer + a summary) into a single interface. | Complex pipelines that need multiple memory strategies simultaneously. |
# | **ConversationTokenBufferMemory** | Similar to `ConversationBufferMemory` but stops adding turns once a token limit is reached. | Token‑budget‑aware bots. |
# | **InMemoryStore / Long‑term memory stores** (via LangGraph) | Simple key‑value or vector‑store backed store that can be persisted across runs. | Persistent user‑specific data, preferences, or long‑term facts. |
#
# ### How to pick one
# - **Need full history?** → `ConversationBufferMemory` (or `BufferMemory` if you want raw messages).
# - **Want only recent turns?** → `ConversationBufferWindowMemory` / `BufferWindowMemory`.
# - **Running out of tokens on long chats?** → `ConversationSummaryMemory` or `ConversationSummaryBufferMemory`.
# - **Need factual recall about entities?** → `EntityMemory` or `ConversationKnowledgeGraphMemory`.
# - **Want semantic retrieval from a large corpus?** → `VectorStoreRetrieverMemory` (backed by Pinecone, FAISS, etc.).
# - **Combine strategies?** → `CombinedMemory`.
#
# These classes all inherit from `BaseChatMemory` (or `BaseMemory`) and expose the same interface (`load_memory_variables`, `save_context`, etc.), so you can swap them in and out of a `ConversationChain`, `LLMChain`, or any LangChain agent with minimal code changes.
